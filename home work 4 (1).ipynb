# %%
# part1

# %%
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
df = pd.read_csv("C:\\Users\\dell\\Desktop\\anaconda\\Pima Indians Diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df = df.sample(frac=1,random_state = 20) 
df = df.reset_index(drop=True)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             10      108             66              0        0  32.4
# 1              5      166             72             19      175  25.8
# 2              3       96             78             39        0  37.3
# 3              8      110             76              0        0  27.8
# 4              0      126             86             27      120  27.4
# ..           ...      ...            ...            ...      ...   ...
# 763            5       85             74             22        0  29.0
# 764            7      142             60             33      190  28.8
# 765            2      108             62             32       56  25.2
# 766            4      114             64              0        0  28.9
# 767            9      165             88              0        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.272   42        1
# ...

# %%
df_train = df.iloc[:614].copy(deep =True)
df_val = df.iloc[614:691].copy(deep =True).reset_index(drop=True) 
df_test = df.iloc[691:].copy(deep =True).reset_index(drop=True)

# %%
print(df_train.shape , df_val.shape , df_test.shape)
# Out:
# (614, 9) (77, 9) (77, 9)

# %%
print(df.shape)
# Out:
# (768, 9)

# %% [markdown]
# #8
# Pregnancies: تعداد دفعات بارداری این ستون نشان می‌دهد که یک زن چند بار باردار شده است.
# Glucose: سطح گلوکز خون (قند خون). این اندازه‌گیری معمولاً پس از ناشتا بودن انجام می‌شود و می‌تواند نشان‌دهنده مشکلاتی مانند دیابت باشد.
# BloodPressure: فشار خون دیاستولیک (عدد پایینی فشار خون). این مقدار بر حسب میلی‌متر جیوه (mmHg) است.
# SkinThickness: ضخامت چین پوستی سه سر بازو. این اندازه‌گیری می‌تواند به تخمین میزان چربی بدن کمک کند.
# Insulin: سطح انسولین سرم. انسولین هورمونی است که به تنظیم قند خون کمک می‌کند.
# BMI: شاخص توده بدنی. این شاخص با تقسیم وزن (به کیلوگرم) بر مجذور قد (به متر) محاسبه می‌شود و معیاری برای ارزیابی وزن نسبت به قد است.
# DiabetesPedigreeFunction: تابع شجره‌نامه دیابت. این یک معیار ژنتیکی است که احتمال ابتلا به دیابت را بر اساس سابقه خانوادگی فرد ارزیابی می‌کند. مقدار بالاتر نشان‌دهنده ریسک بالاتر است.
# Age: سن فرد (بر حسب سال).
# Outcome: نتیجه تشخیص. این ستون نشان می‌دهد که آیا فرد به دیابت مبتلا است یا خیر. مقدار ‘0’ به معنی عدم ابتلا به دیابت و مقدار ‘1’ به معنی ابتلا به دیابت است.

# %%
df_train.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0           10      108             66              0        0  32.4
# 1            5      166             72             19      175  25.8
# 2            3       96             78             39        0  37.3
# 3            8      110             76              0        0  27.8
# 4            0      126             86             27      120  27.4
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.272   42        1
# 1                     0.587   51        1
# 2                     0.238   40        0
# 3                     0.237   58        0
# 4                     0.515   21        0

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               614 non-null    int64
#  1   Glucose                   614 non-null    int64
#  2   BloodPressure             614 non-null    int64
#  3   SkinThickness             614 non-null    int64
#  4   Insulin                   614 non-null    int64
#  5   BMI                       614 non-null    float64
#  6   DiabetesPedigreeFunction  614 non-null    float64
#  7   Age                       614 non-null    int64
#  8   Outcome                   614 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 43.3 KB

# %% [markdown]
# اولین اندیس:1
# آخرین اندیس: 768
# تعداد کل ردیف‌ها: 768

# %%
df_train.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   614.000000  614.000000     614.000000     614.000000  614.000000
# mean      3.724756  121.161238      69.087948      20.750814   81.701954
# std       3.301708   32.848335      19.830326      16.007180  115.837291
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      64.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   36.000000
# 75%       6.000000  141.000000      80.000000      32.000000  130.000000
# max      15.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  614.000000                614.000000  614.000000  614.000000
# mean    32.113192                  0.474873   32.874593    0.366450
# std      7.863379                  0.336785   11.437278    0.482227
# ...

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0           10      108             66              0        0  32.4
# 1            5      166             72             19      175  25.8
# 2            3       96             78             39        0  37.3
# 3            8      110             76              0        0  27.8
# 4            0      126             86             27      120  27.4
# 5            5      109             62             41      129  35.8
# 6            5       97             76             27        0  35.6
# 7            1      140             74             26      180  24.1
# 8            2      128             64             42        0  40.0
# 9            7       81             78             40       48  46.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.272   42        1
# 1                     0.587   51        1
# 2                     0.238   40        0
# ...

# %%
df.tail(3)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 765            2      108             62             32       56  25.2
# 766            4      114             64              0        0  28.9
# 767            9      165             88              0        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 765                     0.128   21        0
# 766                     0.126   24        0
# 767                     0.302   49        1

# %%
df.iloc[:, 4:7]
# Out:
#      Insulin   BMI  DiabetesPedigreeFunction
# 0          0  32.4                     0.272
# 1        175  25.8                     0.587
# 2          0  37.3                     0.238
# 3          0  27.8                     0.237
# 4        120  27.4                     0.515
# ..       ...   ...                       ...
# 763        0  29.0                     1.224
# 764      190  28.8                     0.687
# 765       56  25.2                     0.128
# 766        0  28.9                     0.126
# 767        0  30.4                     0.302
#
# [768 rows x 3 columns]

# %%
df_train.iloc[:20]
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            10      108             66              0        0  32.4
# 1             5      166             72             19      175  25.8
# 2             3       96             78             39        0  37.3
# 3             8      110             76              0        0  27.8
# 4             0      126             86             27      120  27.4
# 5             5      109             62             41      129  35.8
# 6             5       97             76             27        0  35.6
# 7             1      140             74             26      180  24.1
# 8             2      128             64             42        0  40.0
# 9             7       81             78             40       48  46.7
# 10            1      168             88             29        0  35.0
# 11            7      119              0              0        0  25.2
# ...

# %%
df.iloc[14:35, 1:5]
# Out:
#     Glucose  BloodPressure  SkinThickness  Insulin
# 14      106             64             35      119
# 15       72             78             25        0
# 16       97             64             19       82
# 17      102             64             46       78
# 18      136             74             50      204
# 19      115              0              0        0
# 20      108             62             10      278
# 21      106             60             24        0
# 22      130             64              0        0
# 23      130             70             13      105
# 24      187             68             39      304
# 25      102             86             17      105
# 26      135             54              0        0
# 27       80             55              0        0
# 28      197             70             45      543
# 29      115             98              0        0
# 30      162             76             56      100
# ...

# %%
df_train["Pregnancies"]
# Out:
# 0      10
# 1       5
# 2       3
# 3       8
# 4       0
#        ..
# 609     3
# 610     2
# 611     7
# 612    12
# 613     4
# Name: Pregnancies, Length: 614, dtype: int64

# %%
df_train[["BMI","Insulin","Glucose"]]
# Out:
#       BMI  Insulin  Glucose
# 0    32.4        0      108
# 1    25.8      175      166
# 2    37.3        0       96
# 3    27.8        0      110
# 4    27.4      120      126
# ..    ...      ...      ...
# 609  24.7      115       96
# 610  21.1       49       96
# 611  37.2      105      102
# 612  30.0      105      100
# 613  30.9      318      148
#
# [614 rows x 3 columns]

# %%
df_train.loc[df_train["Age"] <= 50]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             10      108             66              0        0  32.4
# 2              3       96             78             39        0  37.3
# 4              0      126             86             27      120  27.4
# 5              5      109             62             41      129  35.8
# 7              1      140             74             26      180  24.1
# ..           ...      ...            ...            ...      ...   ...
# 609            3       96             56             34      115  24.7
# 610            2       96             68             13       49  21.1
# 611            7      102             74             40      105  37.2
# 612           12      100             84             33      105  30.0
# 613            4      148             60             27      318  30.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.272   42        1
# ...

# %%
df_train.loc[df_train["Pregnancies"] == 0]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 4              0      126             86             27      120  27.4
# 13             0      102             78             40       90  34.5
# 17             0      102             64             46       78  40.6
# 25             0      102             86             17      105  29.3
# 30             0      162             76             56      100  53.2
# ..           ...      ...            ...            ...      ...   ...
# 591            0      126             84             29      215  30.7
# 593            0      117              0              0        0  33.8
# 599            0      101             64             17        0  21.0
# 607            0      177             60             29      478  34.6
# 608            0      131             88              0        0  31.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 4                       0.515   21        0
# ...

# %%
df_train.loc[(df_train["BloodPressure"] >= 70) & (df_train["BloodPressure"] <= 100)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              5      166             72             19      175  25.8
# 2              3       96             78             39        0  37.3
# 3              8      110             76              0        0  27.8
# 4              0      126             86             27      120  27.4
# 6              5       97             76             27        0  35.6
# ..           ...      ...            ...            ...      ...   ...
# 602            8      188             78              0        0  47.9
# 603            4      173             70             14      168  29.7
# 608            0      131             88              0        0  31.6
# 611            7      102             74             40      105  37.2
# 612           12      100             84             33      105  30.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.587   51        1
# ...

# %%
df_train.loc[(df_train["Age"] > 50) & (df_train["BMI"] >= 25) & (df_train["BMI"] <= 30)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              5      166             72             19      175  25.8
# 3              8      110             76              0        0  27.8
# 26             1      135             54              0        0  26.7
# 40             8      194             80              0        0  26.1
# 136            4      132             86             31        0  28.0
# 144            6      166             74              0        0  26.6
# 213            7      136             74             26      135  26.0
# 228            0      105             84              0        0  27.9
# 264           10      162             84              0        0  27.7
# 357            2      108             80              0        0  27.0
# 493            7      195             70             33      145  25.1
# 503            8      124             76             24      600  28.7
# ...

# %%
df_train[(df_train["Age"] >= 20) & (df_train["Age"] <= 30)].shape[0]
# Out:
# 339

# %%
df_train.loc[df_train["Outcome"] == 1]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             10      108             66              0        0  32.4
# 1              5      166             72             19      175  25.8
# 5              5      109             62             41      129  35.8
# 6              5       97             76             27        0  35.6
# 10             1      168             88             29        0  35.0
# ..           ...      ...            ...            ...      ...   ...
# 602            8      188             78              0        0  47.9
# 603            4      173             70             14      168  29.7
# 607            0      177             60             29      478  34.6
# 608            0      131             88              0        0  31.6
# 613            4      148             60             27      318  30.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.272   42        1
# ...

# %%
# part2

# %%
# تمرین 1
df_train.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# هیچ  سطر و ستون هایی ناشناخته ای نداریم

# %%
# تمرین 2
df_train.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# تمرین 3
df_train.dropna(axis=0, inplace=True)

# %%
# تمرین 4
df_train = df_train.reset_index(drop=True)

# %%
# تمرین 5
df_train.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# تمرین 6
df_train.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# تمرین 7
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               614 non-null    int64
#  1   Glucose                   614 non-null    int64
#  2   BloodPressure             614 non-null    int64
#  3   SkinThickness             614 non-null    int64
#  4   Insulin                   614 non-null    int64
#  5   BMI                       614 non-null    float64
#  6   DiabetesPedigreeFunction  614 non-null    float64
#  7   Age                       614 non-null    int64
#  8   Outcome                   614 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 43.3 KB

# %%
# part3

# %%
# تمرین 1
(df_train == 0).sum()
# Out:
# Pregnancies                  94
# Glucose                       5
# BloodPressure                30
# SkinThickness               178
# Insulin                     297
# BMI                           9
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     389
# dtype: int64

# %%
# تمرین 2
# Glucose
# BloodPressure
# SkinThickness
# Insulin
# BMI

# %%
# تمرین 3
zero_cols = [
    "Glucose",
    "BloodPressure",
    "SkinThickness",
    "Insulin",
    "BMI"
]

# %%
# تمرین 4
for col in zero_cols:
    median_value = df_train[col].median()

    df_train[col] = df_train[col].replace(0, median_value)

# %%
# تمرین 5
(df_train[zero_cols] == 0).sum()
# Out:
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# dtype: int64

# %%
# تمرین 6
(df_train[zero_cols] == 0).sum()
# Out:
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# dtype: int64
