# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\dell\\Desktop\\anaconda\\Pima Indians Diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df = df.sample(frac=1, random_state=42)

df = df.reset_index(drop=True)

df

# %%
train_df, temp_df = train_test_split(
    df,
    test_size=0.3,
    random_state=42
)

validation_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    random_state=42

# %%
print("Train Shape :", train_df.shape)

print("Validation Shape :", validation_df.shape)

print("Test Shape :", test_df.shape)

# %%
train_df

# %%
train_df.shape

# %%
# Pregnancies : تعداد بارداری
# Glucose : میزان گلوکز خون
# BloodPressure : فشار خون
# SkinThickness : ضخامت پوست
# Insulin : میزان انسولین
# BMI : شاخص توده بدنی
# DiabetesPedigreeFunction : سابقه خانوادگی دیابت
# Age : سن
# Outcome : وضعیت دیابت

# %%
print("Start Index :", train_df.index.min())

print("End Index :", train_df.index.max())

# %%
train_df.select_dtypes(include=np.number).columns

# %%
train_df.columns

# %%
train_df.describe()

# %%
train_df.head(10)

# %%
train_df.tail(10)

# %%
train_df.iloc[:, 0:7]

# %%
train_df.iloc[15:36, 2:6]

# %%
train_df['Pregnancies']

# %%
train_df[['Glucose', 'Insulin', 'BMI']]

# %%
train_df[train_df['Pregnancies'] > 3]

# %%
train_df[train_df['Pregnancies'] == 0]

# %%
train_df[
    (train_df['BloodPressure'] >= 70) &
    (train_df['BloodPressure'] <= 100)
]

# %%
train_df[
    (train_df['Age'] > 50) &
    (train_df['BMI'] >= 25) &
    (train_df['BMI'] <= 30)
]

# %%
count_age = train_df[
    (train_df['Age'] >= 20) &
    (train_df['Age'] <= 30)
].shape[0]

print(count_age)

# %%
diabetic_count = train_df[
    train_df['Outcome'] == 1
].shape[0]

print(diabetic_count)

# %%
# بخش دوم

# %%
# تمرنی 1
df_train.insull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 def_train.insull().sum()
#
# NameError: name 'def_train' is not defined
